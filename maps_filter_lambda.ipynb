# %%
nums = [3,4,5,6,7,8]
for vals in nums:
    print(vals+10)
# Out:
# 13
# 14
# 15
# 16
# 17
# 18

# %%
def add10(variable):
    return variable + 10

# %%
for vals in map(add10,nums):
    print(vals)
# Out:
# 13
# 14
# 15

# %%
list(map(add10,nums))
# Out:
# [13, 14, 15]

# %%
name = 'mohammed'
len(name)
# Out:
# 8

# %%
names = ['mohammed', 'emmanuel', 'joseph', 'chidinma']

# %%
for name in map(len,names):
    print(f'the length of this name is:{name}')
# Out:
# the length of this name is:8
# the length of this name is:8
# the length of this name is:6
# the length of this name is:8

# %%
def even(n):
    return n%2==0

even(7)
# Out:
# False

# %%
# Out:
# False

# %%
list(filter(even,nums))
# Out:
# [4, 6, 8]

# %%
numbers = []
limit = 1

import random
random.seed(9)

while limit<=1000:
    this_num = random.randrange(100,1000)
    numbers.append(this_num)
    limit += 1

print(numbers)
# Out:
# [574, 727, 482, 373, 241, 290, 987, 792, 106, 446, 614, 574, 719, 182, 442, 667, 731, 816, 141, 845, 488, 273, 820, 562, 842, 532, 260, 272, 343, 152, 213, 235, 618, 992, 704, 164, 892, 804, 492, 908, 864, 204, 398, 309, 790, 329, 843, 912, 531, 189, 891, 373, 314, 506, 387, 449, 928, 144, 304, 825, 105, 521, 156, 487, 966, 603, 242, 124, 342, 534, 853, 971, 214, 711, 103, 224, 882, 692, 302, 972, 307, 438, 108, 185, 236, 652, 117, 612, 186, 686, 608, 650, 302, 530, 170, 507, 296, 754, 883, 195, 817, 693, 248, 276, 723, 836, 142, 155, 376, 668, 799, 720, 972, 252, 863, 374, 854, 689, 135, 224, 989, 822, 512, 342, 265, 725, 617, 144, 853, 474, 965, 790, 634, 704, 678, 893, 804, 188, 988, 455, 212, 984, 698, 474, 562, 315, 511, 303, 688, 863, 118, 488, 918, 722, 436, 100, 543, 214, 318, 327, 554, 376, 432, 934, 190, 414, 744, 391, 205, 629, 902, 156, 126, 490, 899, 673, 926, 538, 609, 454, 826, 896, 354, 679, 855, 167, 535, 763, 336, 198, 878, 510, 622, 481, 980, 673, 478, 242, 783, 39
# ...

# %%
print('hello')
# Out:
# hello

# %%
numbers
# Out:
# [574,
#  727,
#  482,
#  373,
#  241,
#  290,
#  987,
#  792,
#  106,
#  446,
#  614,
#  574,
#  719,
#  182,
#  442,
#  667,
#  731,
#  816,
#  141,
#  845,
#  488,
#  273,
#  820,
#  562,
#  842,
#  532,
#  260,
#  272,
#  343,
#  152,
#  213,
#  235,
#  618,
#  992,
#  704,
#  164,
#  892,
#  804,
#  492,
#  908,
#  864,
#  204,
#  398,
#  309,
#  790,
#  329,
#  843,
#  912,
#  531,
#  189,
#  891,
#  373,
#  314,
#  506,
#  387,
#  449,
#  928,
#  144,
#  304,
#  825,
#  105,
#  521,
#  156,
#  487,
#  966,
#  603,
#  242,
#  124,
#  342,
#  534,
#  853,
#  971,
#  214,
#  711,
#  103,
#  224,
#  882,
#  692,
#  302,
#  972,
#  307,
#  438,
#  108,
#  185,
#  236,
#  652,
#  117,
#  612,
#  186,
#  686,
#  608,
#  650,
#  302,
#  530,
#  170,
#  507,
#  296,
#  754,
#  883,
#  195,
#  817,
#  693,
#  248,
#  276,
#  723,
#  836,
#  142,
#  155,
#  376,
#  668,
#  799,
#  720,
#  972,
#  252,
#  863,
#  374,
#  854,
#  689,
#  135,
#  224,
#  989,
#  822,
#  512,
#  342,
#  265,
# ...

# %%
list(filter(lambda x: x>500, numbers))
# Out:
# [574,
#  727,
#  987,
#  792,
#  614,
#  574,
#  719,
#  667,
#  731,
#  816,
#  845,
#  820,
#  562,
#  842,
#  532,
#  618,
#  992,
#  704,
#  892,
#  804,
#  908,
#  864,
#  790,
#  843,
#  912,
#  531,
#  891,
#  506,
#  928,
#  825,
#  521,
#  966,
#  603,
#  534,
#  853,
#  971,
#  711,
#  882,
#  692,
#  972,
#  652,
#  612,
#  686,
#  608,
#  650,
#  530,
#  507,
#  754,
#  883,
#  817,
#  693,
#  723,
#  836,
#  668,
#  799,
#  720,
#  972,
#  863,
#  854,
#  689,
#  989,
#  822,
#  512,
#  725,
#  617,
#  853,
#  965,
#  790,
#  634,
#  704,
#  678,
#  893,
#  804,
#  988,
#  984,
#  698,
#  562,
#  511,
#  688,
#  863,
#  918,
#  722,
#  543,
#  554,
#  934,
#  744,
#  629,
#  902,
#  899,
#  673,
#  926,
#  538,
#  609,
#  826,
#  896,
#  679,
#  855,
#  535,
#  763,
#  878,
#  510,
#  622,
#  980,
#  673,
#  783,
#  809,
#  963,
#  996,
#  929,
#  721,
#  561,
#  905,
#  726,
#  917,
#  592,
#  675,
#  865,
#  669,
#  812,
#  530,
#  562,
#  820,
#  675,
#  882,
#  913,
# ...

# %%
10%3
# Out:
# 1

# %%
nums2 =[1,2,3,4,5,6,7,8,9]
list(filter(lambda n: n%2==1, nums2))
# Out:
# [1, 3, 5, 7, 9]
